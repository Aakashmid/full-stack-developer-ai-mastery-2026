# %% [markdown]
# # Iterative Prompt Development
# In this lesson, we'll iteratively analyze and refine our prompts to generate marketing copy from a product fact sheet.
#
# ### setup

# %%
# load api key and relevant libraries

import openai
import os


from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())


token = os.getenv("GITHUB_TOKEN")
endpoint = "https://models.github.ai/inference"
model = "openai/gpt-4.1"

client = openai.OpenAI(
    base_url=endpoint,
    api_key=token,
)

# %%
# helper function to get a completion from OpenAI API
def get_completion(prompt, model=model):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %% [markdown]
# ### Generate a marketing product description from a product fact sheet

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# **Mid-Century Modern Office Chair – Customizable Comfort & Style**
#
# Elevate your workspace with this stunning mid-century inspired office chair, designed to blend timeless style with modern functionality. Part of a beautifully coordinated furniture collection, this chair is perfect for both home offices and professional environments.
#
# **Customizable Design:**
# Choose from several shell colors and base finishes—including stainless steel, matte black, gloss white, or chrome—to match your décor. Select your preferred upholstery: opt for a sleek plastic back with front upholstery (SWC-100) or indulge in full upholstery (SWC-110), available in 10 premium fabrics and 6 luxurious leathers.
#
# **Tailored Comfort:**
# Enjoy ergonomic support with a pneumatic height adjustment and a choice of medium or high-density HD36 foam seat cushions. The chair is available with or without armrests, including 8-position PU armrests for personalized comfort.
#
# **Durable Construction:**
# Crafted in Italy, the chair features a robust 5-wheel plastic-coated aluminum base and a 10 mm thick cast aluminum shell with modified nylon coating for lasting durability. Choose soft or hard-floor casters to suit your space.
#
# **Dimensions:**
# - Width: 53 cm (20.87”)
# - Depth: 51 cm (20.08”)
# - Height: 80 cm (31.50”)
# - Seat Height: 44 cm (17.32”)
# - Seat Depth: 41 cm (16.14”)
#
# **Versatile & Contract-Ready:**
# Ideal for both residential and commercial use, this chair is qualified for contract settings, ensuring reliability and style wherever you need it.
#
# **Made in Italy.**
# Discover the perfect blend of comfort, customization, and mid-century elegance for your office.

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Elevate your workspace with this Italian-made, mid-century inspired office chair. Customizable in color, upholstery, and base finish, it features ergonomic adjustments, premium HD36 foam, and durable aluminum construction. Perfect for home or business, with options for armrests, caster types, and seat foam density.

# %%
len(response.split())
# Out:
# 43

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# - Ask it to focus on the aspects that are relevant to the intended audience.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted in Italy, this office chair features a 10 mm cast aluminum shell with durable PA6/PA66 nylon coating, a 5-wheel plastic-coated aluminum base, and HD36 foam seat. Choose from multiple upholstery, base finishes, foam densities, and armrest options for versatile contract or home use.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Constructed in Italy, this mid-century inspired office chair features a 10mm cast aluminum shell with modified nylon PA6/PA66 coating, HD36 foam seat, and a 5-wheel plastic-coated aluminum base. Available in multiple finishes, upholstery, and foam densities. Suitable for contract use. Product IDs: SWC-100, SWC-110

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)

# %%
# load python libraries to view HTML
from IPython.display import display, HTML
display(HTML(response))
# Out:
# ```html
# <div>
# The SWC Series office chair is a premium seating solution designed for both home and contract environments, drawing inspiration from mid-century aesthetics. Constructed with a robust shell made from cast aluminum, the chair features a modified nylon PA6/PA66 coating for enhanced durability and a shell thickness of 10 mm. The 5-wheel base is crafted from plastic-coated aluminum, ensuring stability and smooth mobility.
#
# The seat utilizes high-quality HD36 foam, available in two densities—medium (1.8 lb/ft³) or high (2.8 lb/ft³)—to suit different comfort preferences. Upholstery options include a plastic back with front upholstery (SWC-100) or full upholstery (SWC-110), offered in a selection of 10 fabrics and 6 leathers. The chair base is available in stainless steel, matte black, gloss white, or chrome finishes, and can be configured with or without armrests, including 8-position PU armrests.
#
# Additional features include pneumatic height adjustment and a choice of soft or hard-floor casters. The SWC Series is manufactured in Italy and is qualified for contract use, making it an ideal choice for furniture retailers seeking technically advanced, versatile office seating.
#
# Product IDs: SWC-100, SWC-110
# </div>
#
# <table>
#   <caption><strong>Product Dimensions</strong></caption>
#   <tr>
#     <td>Width</td>
#     <td>20.87”</td>
#   </tr>
#   <tr>
#     <td>Depth</td>
#     <td>20.08”</td>
#   </tr>
#   <tr>
#     <td>Height</td>
#     <td>31.50”</td>
#   </tr>
#   <tr>
#     <td>Seat Height</td>
#     <td>17.32”</td>
#   </tr>
#   <tr>
#     <td>Seat Depth</td>
#     <td>16.14”</td>
#   </tr>
# </table>
# ```

# %% [markdown]
# ### more experimented prompts

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

use at most 30 words ,  one line should not contain more than 7 words 

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted in Italy, this chair features a 10 mm cast aluminum shell.
# Modified nylon PA6/PA66 coating ensures durability.
# HD36 foam seat offers comfort.
# Choose stainless steel, matte black, chrome, or gloss white base.
# Plastic coated aluminum 5-wheel base.
# Available with soft or hard-floor casters.
